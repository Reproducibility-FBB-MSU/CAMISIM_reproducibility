# %% [markdown]
# megahit 1.0.3

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128]
plt.plot([3.09, 71.55, 97.889, 98.172, 98.177, 98.179, 98.166], color = 'g')
plt.plot([2.912, 70.222, 97.884, 98.189, 98.204, 98.191, 98.228], color = 'orange')
plt.plot([0.11, 0.573, 23.127, 70.511, 90.4684, 97.867, 92.158], color = 'red')
xticks(range(7), labels)
plt.ylabel('Genome fraction (%)')
plt.xlabel('Coverage')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128]
plt.plot([186, 2640, 4279, 115, 97, 103, 106], color = 'g')
plt.plot([181, 2647, 432, 116, 104, 102, 109], color = 'orange')
plt.plot([6, 38, 1443, 3422, 3077, 606, 1754], color = 'red')
xticks(range(7), labels)
plt.ylabel('# contigs') 
plt.xlabel('Coverage')
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128]
plt.plot([None,1103,17653,94957,125239,95910,97561], color = 'g')
plt.plot([None,1059,17488,94890,105749,95619,112590], color = 'orange')
plt.plot([None,None,None,846,1652,11711,3773], color = 'red')
xticks(range(7), labels)
plt.ylabel('NGA50') 
plt.xlabel('Coverage') 
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# megahit 1.1.2

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128, 256, 512]
plt.plot([4.091, 79.443, 98.013, 98.175, 98.157, 98.206, 98.194, 98.218, 98.181], color = 'g')
plt.plot([4.078, 78.674, 98.033, 98.171, 98.175, 98.174, 98.206, 98.234, 98.164], color = 'orange')
plt.plot([0.203, 39.998, 39.998, 94.967, 97.877, 98.13, 98.208, 98.181, 98.214], color = 'red')
xticks(range(9), labels)
plt.ylabel('Genome fraction (%)')
plt.xlabel('Coverage') 
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128, 256, 512]
plt.plot([2222,4082,303,158,147,148,150,145,183], color = 'g')
plt.plot([2190,4195,355,150,162,159,155,153,189], color = 'orange')
plt.plot([44,983,6235,2957,892,208,193,229,353], color = 'red')
xticks(range(9), labels)
plt.ylabel('# contigs') 
plt.xlabel('Coverage') 
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128, 256, 512]
plt.plot([None,1589,31487,94837,97786,95514,111779,97552,97554], color = 'g')
plt.plot([None,1501,30671,82949,97574,97807,95519,95522,82817], color = 'orange')
plt.plot([None, None, None, 3175,10455,53595,83358,111771,97563], color = 'red')
xticks(range(9), labels)
plt.ylabel('NGA50') 
plt.xlabel('Coverage') 
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# metaSPAdes 3.12.0

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128]
plt.plot([0.177,1.282, 49.224, 96.739, 97.664, 97.848, 97.848], color = 'g')
plt.plot([1.167, 95.814, 97.814, 98.165, 98.307, 98.174,98.302], color = 'orange')
plt.plot([0.035,0.231,0.351, 52.345,97.916,98.231], color = 'red')
xticks(range(7), labels)
plt.ylabel('Genome fraction (%)')
plt.xlabel('Coverage') 
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128, 256, 512]
plt.plot([9,87,3045,1320,672,210,210], color = 'g')
plt.plot([64,85,346,435,117,102,75], color = 'orange')
plt.plot([2,8,12,2406,259,119,173], color = 'red')
xticks(range(7), labels)
plt.ylabel('# contigs') 
plt.xlabel('Coverage')
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# %pylab inline
import matplotlib.pyplot as plt 
labels = [2, 4, 8, 16, 32, 64, 128]
plt.plot([None,None,None,4993,11401,38008,38008], color = 'g')
plt.plot([None,None,21930,16759,72339,57891,132549], color = 'orange')
plt.plot([None,None,None,550,32142,67333,42240], color = 'red')
xticks(range(7), labels)
plt.ylabel('NGA50') 
plt.xlabel('Coverage')
plt.yscale('log')
plt.show()
# Out:
# Populating the interactive namespace from numpy and matplotlib
